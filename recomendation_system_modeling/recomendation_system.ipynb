# %% [markdown]
# # Projeto 4 - Recomendação de vinhos - Wine Reviews

# %% [markdown]
# # Enunciado

# %% [markdown]
# ## Wine Reviews - Kaggle

# %% [markdown]
# O conjunto de dados Wine Reviews possui o comentário e a nota dada por cada especialista sobre diversos vinhos. O autor se inspirou para fazer este conjunto de dados após assistir Somm, um documentário sobre mestres sommeliers de vinho.

# %% [markdown]
# ## Preparação do ambiente

# %% [markdown]
# * Para este projeto, acessem o link do Kaggle e, logo abaixo, cliquem em "Download". Caso você não tenha uma conta no Kaggle, crie uma e retorne para esse ponto para realizar o download. Descompacte o arquivo.
# * Crie o projeto no Github
# * Use o cookiecutter para organizar o projeto
# * Leia todo o material disponibilizado no Kaggle para entender esses dados
# * Caso precise, leia outros projetos que usaram este mesmo conjunto de dados

# %% [markdown]
# ## Projeto

# %% [markdown]
# <ol>
#     <li>Use os passos do Crisp-DM para desenvolver o projeto.</li>
#     <li>Observe os dados e busque levantar observações importantes, tais como:</li>
#     <ol>
#         <li>Qual vinho é o mais caro? E o mais barato?</li>
#         <li>Qual especialista avaliou mais vinhos? Qual a sua nota média?</li>
#         <li>Qual região possui os vinhos com as maiores avaliações? E qual possui os vinhos mais baratos?<?li>
#     </ol>
#     <li>Faça o sistema de recomendação</li>
#     <li>Escreva o relatório</li>
#     <li>Disponibilize o repositório do seu projeto</li>
# </ol>

# %% [markdown]
# ## Exercícios

# %% [markdown]
# Separe o notebook entre analise exploratória, construção do sistema de recomendação e relatório.
# 1. (3 pontos) **Análise exploratória**: realize as análises deste conjunto de dados, crie gráficos e anote as suas idéias.
# 2. (3 pontos) **Sistema de recomendação**: faça a construção de seu sistema de recomendação
# 3. (4 pontos) **Relatório**: construa um relatório utilizando o Markdown para escrever. Seja criativo para apresentar seus achados e siga os passos abaixo:
#     * Imagine que você possui uma startup e este é o primeiro relatório apresentará
#     * Coloque o nome do seu produto
#     * Apresente a introdução do problema (seja sucinto, escreva com poucas palavras)
#     * Coloque gráficos e frases para sustentar seus argumentos
#     * Mostre as soluções do mercado
#     * Escreva sobre a sua solução e por que ela é a melhor

# %% [markdown]
# # 2. (3 pontos) **Sistema de recomendação**: faça a construção de seu sistema de recomendação

# %% [markdown]
# ## Sistema de Recomendação

# %% [markdown]
# ### Leitura dos dados necessários

# %%
import pandas as pd

system_data = pd.read_csv('../data/processed/wines_recomendation_system.csv')
user_data = pd.read_csv('../data/processed/wines_user_consult.csv')

# %% [markdown]
# ### Implementação dos modelos de classificação.
#
# Serão testados dois modelos um utilizando o TfidfVectorizer e outro utilizando o CountVectorizer

# %% [markdown]
# #### Implementação do TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer()
tfidf_jobid = tfidf_vectorizer.fit_transform(system_data.description)
tfidf_jobid
# Out:
# <117236x22352 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2878782 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Implementação do CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer()
count_jobid = count_vectorizer.fit_transform(system_data.description)
count_jobid
# Out:
# <117236x22352 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2878782 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### Testando os modelos

# %% [markdown]
# Variável de teste.

# %%
data_test = system_data.sample(frac = 0.01)
data_test.shape
# Out:
# (1172, 2)

# %%
from sklearn.neighbors import NearestNeighbors

KNN_tfidf = NearestNeighbors(n_neighbors=11, metric='cosine')
KNN_tfidf.fit(tfidf_jobid)
avg_dist = 0
for row in range(len(data_test)):
    test = data_test.iloc[row]['description']
    user_tfidf = tfidf_vectorizer.transform([test])
    NNs_tfidf = KNN_tfidf.kneighbors(user_tfidf, return_distance=True)
    avg_dist += NNs_tfidf[0][0][1:].mean()
avg_dist /= len(data_test)

print('A distância média do conjunto de teste foi de:', avg_dist)
# Out:
# A distância média do conjunto de teste foi de: 0.6809220977485865

# %%
KNN = NearestNeighbors(n_neighbors=11, metric='cosine')
KNN.fit(count_jobid)
avg_dist = 0
for row in range(len(data_test)):
    test = data_test.iloc[row]['description']
    user_count = count_vectorizer.transform([test])
    NNs = KNN.kneighbors(user_count, return_distance=True)
    avg_dist += NNs[0][0][1:].mean()
avg_dist /= len(data_test)

print('A distância média do conjunto de teste foi de:', avg_dist)
# Out:
# A distância média do conjunto de teste foi de: 0.5687918682750208

# %% [markdown]
# Como o modelo utilizando CountVectorizer produziu a menor distância média no grupo de teste ele será utilizado no modelo de produção.

# %% [markdown]
# A seguir está um exemplo de teste mostrando a diferença dos resultados entre o modelo utilizando o TfidfVectorizer e o CountVectorizer.

# %% [markdown]
# Resultado da classificação pelo TfidfVectorizer

# %%
answer = user_data.loc[NNs_tfidf[1][0, :]]
answer['similarity'] = NNs_tfidf[0][0, :]
answer
# Out:
#              country                                        description  \
# 55504             US  From an estate vineyard and given very little ...
# 111139            US  There's a chalky baking soda touch to the nose...
# 82949             US  Vibrant in apple blossom and coconut, this vol...
# 43165             US  Fresh apple blossoms, lemon-lime soda and frag...
# 95325             US  Given time in both French oak and stainless-st...
# 84391          Italy  This has heady floral aromas of honeysuckle an...
# 63480             US  This white invites you in with floral, citrus ...
# 70727             US  This is a pretty wine in terms of floral aroma...
# 54088             US  Feral and smoky, this light-bodied, light-colo...
# 68548   South Africa  Pretty aromas of yellow florals, wood-grilled ...
# 33341             US  Fruity and floral smelling, this has key aroma...
#
#         points      price      province  \
# 55504       91  53.000000    California
# 111139      89  14.000000    California
# 82949       90  45.000000    California
# 43165       88  25.000000    California
# 95325       86  14.000000    California
# 84391       88  17.000000       Tuscany
# 63480       88  35.368644    California
# 70727       89  34.000000    California
# 54088       91  55.000000    California
# 68548       85  10.000000  Western Cape
# 33341       85   8.000000      Missouri
#
#                                                     title           variety  \
# 55504          Small Vines 2013 Chardonnay (Sonoma Coast)        Chardonnay
# 111139                     Jekel 2015 Riesling (Monterey)          Riesling
# 82949   Silverpoint Cellars 2013 Chardonnay (Sonoma Co...        Chardonnay
# 43165   Darcie Kent Vineyards 2015 Rava Blackjack Vine...  Grüner Veltliner
# 95325      Ferrari-Carano 2014 Fumé Blanc (Sonoma County)        Fumé Blanc
# 84391   Guicciardini Strozzi 2015 Villa Cusona  (Verna...         Vernaccia
# 63480          Moniker 2012 Chardonnay (Mendocino County)        Chardonnay
# 70727   Pine Ridge 2013 Dijon Clones Chardonnay (Carne...        Chardonnay
# 54088          Small Vines 2013 Pinot Noir (Sonoma Coast)        Pinot Noir
# 68548   Releaf 2011 Made With Organically Grown Grapes...      Chenin Blanc
# 33341   Les Bourgeois 2011 La Belle Semi Dry White (Mi...       White Blend
#
#                        winery                     style  similarity
# 55504             Small Vines  Light-Bodied White Wines    0.000000
# 111139                  Jekel      Aromatic White Wines    0.721589
# 82949     Silverpoint Cellars  Light-Bodied White Wines    0.735321
# 43165   Darcie Kent Vineyards  Light-Bodied White Wines    0.750956
# 95325          Ferrari-Carano  Light-Bodied White Wines    0.757356
# 84391    Guicciardini Strozzi   Full-Bodied White Wines    0.775202
# 63480                 Moniker  Light-Bodied White Wines    0.775815
# 70727              Pine Ridge  Light-Bodied White Wines    0.779720
# 54088             Small Vines    Light-Bodied Red Wines    0.780392
# 68548                  Releaf      Aromatic White Wines    0.783559
# 33341           Les Bourgeois   Full-Bodied White Wines    0.784814

# %% [markdown]
# Resultado da classificação pelo CountVectorizer

# %%
answer = user_data.loc[NNs[1][0, :]]
answer['similarity'] = NNs[0][0, :]
answer
# Out:
#        country                                        description  points  \
# 55504       US  From an estate vineyard and given very little ...      91
# 63480       US  This white invites you in with floral, citrus ...      88
# 82949       US  Vibrant in apple blossom and coconut, this vol...      90
# 54088       US  Feral and smoky, this light-bodied, light-colo...      91
# 21575       US  Gravelly texture gives way to faint apple, pre...      88
# 70727       US  This is a pretty wine in terms of floral aroma...      89
# 81567       US  Grown on a family-owned vineyard and aged in 2...      90
# 78065       US  This vineyard-designate rocks its way into you...      93
# 116250      US  Stone, lime salt and lemon zest pique the entr...      90
# 90418       US  A woody, toasted note speaks to well-integrate...      91
# 67031       US  The nose on this dry, medium-bodied wine is fa...      90
#
#             price    province  \
# 55504   53.000000  California
# 63480   35.368644  California
# 82949   45.000000  California
# 54088   55.000000  California
# 21575   42.000000  California
# 70727   34.000000  California
# 81567   55.000000  California
# 78065   45.000000  California
# 116250  32.000000  California
# 90418   24.000000  California
# 67031   16.000000    New York
#
#                                                     title          variety  \
# 55504          Small Vines 2013 Chardonnay (Sonoma Coast)       Chardonnay
# 63480          Moniker 2012 Chardonnay (Mendocino County)       Chardonnay
# 82949   Silverpoint Cellars 2013 Chardonnay (Sonoma Co...       Chardonnay
# 54088          Small Vines 2013 Pinot Noir (Sonoma Coast)       Pinot Noir
# 21575           Clif Family 2015 Chardonnay (Napa Valley)       Chardonnay
# 70727   Pine Ridge 2013 Dijon Clones Chardonnay (Carne...       Chardonnay
# 81567   Tognetti 2013 Aloise Francisco Vineyards Chard...       Chardonnay
# 78065   Lost Canyon 2013 Morelli Lane Vineyard Pinot N...       Pinot Noir
# 116250  Kokomo 2015 Peters Vineyard Chardonnay (Russia...       Chardonnay
# 90418             Hall 2015 Sauvignon Blanc (Napa Valley)  Sauvignon Blanc
# 67031                Damiani 2012 Riesling (Finger Lakes)         Riesling
#
#                      winery                     style    similarity
# 55504           Small Vines  Light-Bodied White Wines  3.330669e-16
# 63480               Moniker  Light-Bodied White Wines  6.726732e-01
# 82949   Silverpoint Cellars  Light-Bodied White Wines  6.894705e-01
# 54088           Small Vines    Light-Bodied Red Wines  7.039217e-01
# 21575           Clif Family  Light-Bodied White Wines  7.113249e-01
# 70727            Pine Ridge  Light-Bodied White Wines  7.192550e-01
# 81567              Tognetti  Light-Bodied White Wines  7.239738e-01
# 78065           Lost Canyon    Light-Bodied Red Wines  7.239738e-01
# 116250               Kokomo  Light-Bodied White Wines  7.241614e-01
# 90418                  Hall  Light-Bodied White Wines  7.284623e-01
# 67031               Damiani      Aromatic White Wines  7.327388e-01

# %% [markdown]
# Modelo final

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import CountVectorizer

system_data = pd.read_csv('../data/processed/wines_recomendation_system.csv')
user_data = pd.read_csv('../data/processed/wines_user_consult.csv')

count_vectorizer = CountVectorizer()
count_jobid = count_vectorizer.fit_transform(system_data.description)

KNN = NearestNeighbors(n_neighbors=11, metric='cosine')
KNN.fit(count_jobid)

test = system_data.loc[10, :].to_frame().T

user_count = count_vectorizer.transform(test.description)
NNs = KNN.kneighbors(user_count, return_distance=True)

answer = user_data.loc[NNs[1][0, :]]
answer['similarity'] = NNs[0][0, :]

# %%
answer
# Out:
#           country                                        description  points  \
# 10             US  Soft, supple plum envelopes an oaky structure ...      87
# 112230     France  This is a caramel-flavored blend of Merlot, Ta...      85
# 39264      France  A big, burly wine with attractive tannins and ...      86
# 93044      France  This is a soft and fruity wine. It has gentle ...      86
# 106762         US  Oodles of rich, ripe fruit in this soft, gentl...      86
# 45831       Spain  The goofy name is questionable, but the wine i...      90
# 102621         US  Herbal peppercorn cradles a soft composition w...      88
# 5978           US  A majority Cabernet Sauvignon, with 15% Merlot...      87
# 32283      France  This dense wine has black plum and chocolate f...      91
# 82165   Australia  Fairly full-bodied and lush, with berry fruit ...      87
# 74605          US  Half of this wine is Merlot, with the rest Cab...      88
#
#             price          province  \
# 10      19.000000        California
# 112230  12.000000  Southwest France
# 39264   15.000000  Southwest France
# 93044   12.000000  Southwest France
# 106762  28.000000        California
# 45831   25.000000         Catalonia
# 102621  90.000000        California
# 5978    48.000000        California
# 32283   35.368644          Bordeaux
# 82165   30.000000   South Australia
# 74605   12.000000        Washington
#
#                                                     title  \
# 10      Kirkland Signature 2011 Mountain Cuvée Caberne...
# 112230  Domaine de Pellehaut 2016 Harmonie de Gascogne...
# 39264                 Domaine Brunet 2009 Malbec (Cahors)
# 93044     Domaine D'en Ségur 2016 Le Rosé (Côtes du Tarn)
# 106762  Leal Vineyards 2005 MacWilliamson Vineyard Pet...
# 45831        Picolino 2012 Suprafabulicious Red (Priorat)
# 102621  Terra Valentine 2011 Marriage Red (Spring Moun...
# 5978    Terra Valentine 2012 Estate Grown Cabernet Sau...
# 32283                 Château Vieux Maillet 2009  Pomerol
# 82165   Kangarilla Road 2008 Black St. Peters Zinfande...
# 74605   Columbia Crest 2013 Grand Estates Red (Columbi...
#
#                          variety                 winery  \
# 10            Cabernet Sauvignon     Kirkland Signature
# 112230                      Rosé   Domaine de Pellehaut
# 39264                     Malbec         Domaine Brunet
# 93044                       Rosé     Domaine D'en Ségur
# 106762              Petite Sirah         Leal Vineyards
# 45831                  Red Blend               Picolino
# 102621  Bordeaux-style Red Blend        Terra Valentine
# 5978          Cabernet Sauvignon        Terra Valentine
# 32283   Bordeaux-style Red Blend  Château Vieux Maillet
# 82165                  Zinfandel        Kangarilla Road
# 74605                  Red Blend         Columbia Crest
#
#                           style  similarity
# 10        Full-Bodied Red Wines    0.000000
# 112230               Rosé Wines    0.622036
# 39264     Full-Bodied Red Wines    0.622876
# 93044                Rosé Wines    0.650851
# 106762    Full-Bodied Red Wines    0.660450
# 45831     Full-Bodied Red Wines    0.661938
# 102621    Full-Bodied Red Wines    0.665748
# 5978      Full-Bodied Red Wines    0.666377
# 32283     Full-Bodied Red Wines    0.670017
# 82165   Medium-Bodied Red Wines    0.670017
# 74605     Full-Bodied Red Wines    0.671366

# %% [markdown]
# Exportando modelo de produção

# %%
from joblib import dump, load

dump(KNN, '../app/classifier.joblib')
dump(count_vectorizer, '../app/vectorizer.joblib')
# Out:
# ['../app/vectorizer.joblib']

# %%
clf = load('../app/classifier.joblib') 
vetorizador = load('../app/vectorizer.joblib')

user_count_vec = vetorizador.transform(test.description)
NNs_clf = clf.kneighbors(user_count_vec, return_distance=True)
answer = user_data.loc[NNs_clf[1][0, :]]
answer['similarity'] = NNs_clf[0][0, :]
answer
# Out:
#           country                                        description  points  \
# 10             US  Soft, supple plum envelopes an oaky structure ...      87
# 112230     France  This is a caramel-flavored blend of Merlot, Ta...      85
# 39264      France  A big, burly wine with attractive tannins and ...      86
# 93044      France  This is a soft and fruity wine. It has gentle ...      86
# 106762         US  Oodles of rich, ripe fruit in this soft, gentl...      86
# 45831       Spain  The goofy name is questionable, but the wine i...      90
# 102621         US  Herbal peppercorn cradles a soft composition w...      88
# 5978           US  A majority Cabernet Sauvignon, with 15% Merlot...      87
# 32283      France  This dense wine has black plum and chocolate f...      91
# 82165   Australia  Fairly full-bodied and lush, with berry fruit ...      87
# 74605          US  Half of this wine is Merlot, with the rest Cab...      88
#
#             price          province  \
# 10      19.000000        California
# 112230  12.000000  Southwest France
# 39264   15.000000  Southwest France
# 93044   12.000000  Southwest France
# 106762  28.000000        California
# 45831   25.000000         Catalonia
# 102621  90.000000        California
# 5978    48.000000        California
# 32283   35.368644          Bordeaux
# 82165   30.000000   South Australia
# 74605   12.000000        Washington
#
#                                                     title  \
# 10      Kirkland Signature 2011 Mountain Cuvée Caberne...
# 112230  Domaine de Pellehaut 2016 Harmonie de Gascogne...
# 39264                 Domaine Brunet 2009 Malbec (Cahors)
# 93044     Domaine D'en Ségur 2016 Le Rosé (Côtes du Tarn)
# 106762  Leal Vineyards 2005 MacWilliamson Vineyard Pet...
# 45831        Picolino 2012 Suprafabulicious Red (Priorat)
# 102621  Terra Valentine 2011 Marriage Red (Spring Moun...
# 5978    Terra Valentine 2012 Estate Grown Cabernet Sau...
# 32283                 Château Vieux Maillet 2009  Pomerol
# 82165   Kangarilla Road 2008 Black St. Peters Zinfande...
# 74605   Columbia Crest 2013 Grand Estates Red (Columbi...
#
#                          variety                 winery  \
# 10            Cabernet Sauvignon     Kirkland Signature
# 112230                      Rosé   Domaine de Pellehaut
# 39264                     Malbec         Domaine Brunet
# 93044                       Rosé     Domaine D'en Ségur
# 106762              Petite Sirah         Leal Vineyards
# 45831                  Red Blend               Picolino
# 102621  Bordeaux-style Red Blend        Terra Valentine
# 5978          Cabernet Sauvignon        Terra Valentine
# 32283   Bordeaux-style Red Blend  Château Vieux Maillet
# 82165                  Zinfandel        Kangarilla Road
# 74605                  Red Blend         Columbia Crest
#
#                           style  similarity
# 10        Full-Bodied Red Wines    0.000000
# 112230               Rosé Wines    0.622036
# 39264     Full-Bodied Red Wines    0.622876
# 93044                Rosé Wines    0.650851
# 106762    Full-Bodied Red Wines    0.660450
# 45831     Full-Bodied Red Wines    0.661938
# 102621    Full-Bodied Red Wines    0.665748
# 5978      Full-Bodied Red Wines    0.666377
# 32283     Full-Bodied Red Wines    0.670017
# 82165   Medium-Bodied Red Wines    0.670017
# 74605     Full-Bodied Red Wines    0.671366
